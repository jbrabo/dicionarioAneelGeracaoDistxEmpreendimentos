# %% [markdown]
# # INICIANDO A CRIAÇÃO DO DICIONÁRIO DAS COLUNAS DA ANEEL
# ## ESSE DICIONÁRIO SERVE DE BASE PARA O ESTUDO DA BASE DE DADOS DISPONIBILIZADOS PELA ANEEL
# ### O ARQUIVO CONSTRUÍDO AO FINAL EXPLICA CADA COLUNA DAS TABELAS PRESENTE NA BASE DE DADOS DA ANEEL
# ### SERÁ LINKADO COMO INFO DE TODOS AS COLUNAS NA HORA DE ELABORAR A ANÁLISE DO NOSSO DOCUMENTO

# %%
pip install tabula-py
# Out:
# Requirement already satisfied: tabula-py in c:\users\jvbra\anaconda3\lib\site-packages (2.9.0)
# Requirement already satisfied: pandas>=0.25.3 in c:\users\jvbra\anaconda3\lib\site-packages (from tabula-py) (2.1.3)
# Requirement already satisfied: numpy in c:\users\jvbra\anaconda3\lib\site-packages (from tabula-py) (1.26.2)
# Requirement already satisfied: distro in c:\users\jvbra\anaconda3\lib\site-packages (from tabula-py) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jvbra\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jvbra\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jvbra\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\jvbra\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.25.3->tabula-py) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jpype1
# Out:
# Requirement already satisfied: jpype1 in c:\users\jvbra\anaconda3\lib\site-packages (1.4.1)
# Requirement already satisfied: packaging in c:\users\jvbra\anaconda3\lib\site-packages (from jpype1) (23.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tabula
import pandas as pd

arquivo = "https://dadosabertos.aneel.gov.br/dataset/5e0fafd2-21b9-4d5b-b622-40438d40aba2/resource/3fabb9e8-668a-4f94-8f0e-ed9cd2682979/download/dm-geracao-distribuida-relacao-de-empreendimentos.pdf"
pages = 'all'   
list_tabelas = tabula.read_pdf(arquivo, pages=pages)

print(len(list_tabelas))
# Out:
# 3

# %%
import tabula

arquivo = "https://dadosabertos.aneel.gov.br/dataset/5e0fafd2-21b9-4d5b-b622-40438d40aba2/resource/3fabb9e8-668a-4f94-8f0e-ed9cd2682979/download/dm-geracao-distribuida-relacao-de-empreendimentos.pdf"

list_tabelas = tabula.read_pdf(arquivo, pages=["3","4","5"])

print(len(list_tabelas))
# Out:
# 3

# %%
for tabela in list_tabelas:
    display(tabela)
# Out:
#                  Unnamed: 0            Unnamed: 1 Tamanho do  \
# 0             Nome do Campo          Tipo de dado      campo
# 1                       NaN                   NaN        NaN
# 2   DatGeracaoConjuntoDados          data simples        NaN
# 3                       NaN                   NaN        NaN
# 4      AnmPeriodoReferencia  Cadeia de caracteres          7
# 5      NumCNPJDistribuidora  Cadeia de caracteres         14
# 6                 SigAgente  Cadeia de caracteres         20
# 7                 NomAgente  Cadeia de caracteres        200
# 8          CodClasseConsumo              Numérico        NaN
# 9          DscClasseConsumo  Cadeia de caracteres         20
# 10     CodSubGrupoTarifario              Numérico        NaN
# 11                      NaN                   NaN        NaN
# 12                      NaN                   NaN        NaN
# 13                      NaN                   NaN        NaN
# 14                      NaN                   NaN        NaN
# 15                      NaN                   NaN        NaN
# 16     DscSubGrupoTarifario  Cadeia de caracteres         10
# 17                      NaN                   NaN        NaN
# 18                      NaN                   NaN        NaN
# 19                      NaN                   NaN        NaN
# 20                      NaN                   NaN        NaN
# 21                      NaN                   NaN        NaN
# 22                      NaN                   NaN        NaN
# 23                CodUFibge  Cadeia de caracteres          2
# 24                      NaN                   NaN        NaN
# 25                      NaN                   NaN        NaN
# 26                    SigUF  Cadeia de caracteres          2
# 27                      NaN                   NaN        NaN
# 28                      NaN                   NaN        NaN
# 29                CodRegiao  Cadeia de caracteres          4
# 30                      NaN                   NaN        NaN
#
#                                            Unnamed: 2
# 0                                           Descrição
# 1   Data e hora do processamento de carga automáti...
# 2                                                 NaN
# 3            publicação do conjunto de dados abertos.
# 4                   Ano e mês de referência dos dados
# 5             Cadastro Nacional de Pessoas Jurídicas.
# 6   Sigla que abrevia o nome do Agente de Geração ...
# 7               Nome do Agente de Geração Distribuída
# 8   Código que representa a classificação de consu...
# 9   Descrição da classificação de consumo das unid...
# 10     Código que representa os subgrupos tarifários.
# 11  Grupamento de unidades consumidoras de acordo ...
# 12  A1 - tensão de fornecimento igual ou superior ...
# 13      A2 - tensão de fornecimento de 88 kV a 138 kV
# 14               A3 - tensão de fornecimento de 69 kV
# 15      A3a - tensão de fornecimento de 30 kV a 44 kV
# 16      A4 - tensão de fornecimento de 2,3 kV a 25 kV
# 17                                   AS - subterrâneo
# 18                                   B1 - residencial
# 19                                         B2 - rural
# 20                                B3 - demais classes
# 21                            B4 - iluminação pública
# 22  Código do IBGE referente ao Estado do Brasil e...
# 23                                                NaN
# 24                            de Geração Distribuída.
# 25  Sigla do IBGE referente ao Estado do Brasil em...
# 26                                                NaN
# 27                               Geração Distribuída.
# 28  Código Externo do IBGE referente a Meso Região...
# 29                                                NaN
# 30             Empreendimento de Geração Distribuída.
#                       Unnamed: 0            Unnamed: 1  Unnamed: 2  \
# 0                      NomRegiao  Cadeia de caracteres        50.0
# 1                            NaN                   NaN         NaN
# 2                            NaN                   NaN         NaN
# 3               CodMunicipioIbge              Numérico         NaN
# 4                            NaN                   NaN         NaN
# 5                            NaN                   NaN         NaN
# 6                   NomMunicipio  Cadeia de caracteres        40.0
# 7                            NaN                   NaN         NaN
# 8                            NaN                   NaN         NaN
# 9              SigTipoConsumidor  Cadeia de caracteres         2.0
# 10                           NaN                   NaN         NaN
# 11                           NaN                   NaN         NaN
# 12                    NumCpfCnpj  Cadeia de caracteres        14.0
# 13                           NaN                   NaN         NaN
# 14      NomTitularEmpreendimento  Cadeia de caracteres      8000.0
# 15             CodEmpreendimento  Cadeia de caracteres        21.0
# 16  DthAtualizaCadastralEmpreend             Data hora         NaN
# 17                           NaN                   NaN         NaN
# 18                           NaN                   NaN         NaN
# 19                           NaN                   NaN         NaN
# 20   SigModalidadeEmpreendimento  Cadeia de caracteres         1.0
# 21                           NaN                   NaN         NaN
# 22                           NaN                   NaN         NaN
# 23                           NaN                   NaN         NaN
# 24                           NaN                   NaN         NaN
# 25                           NaN                   NaN         NaN
# 26       DscModalidadeHabilitado  Cadeia de caracteres        50.0
# 27                           NaN                   NaN         NaN
# 28                           NaN                   NaN         NaN
#
#    Nome da Meso Região atribuído pelo IBGE em que se situa o Empreendimento de
# 0                                                 NaN
# 1                                Geração Distribuída.
# 2   Código Externo do IBGE referente ao Município ...
# 3                                                 NaN
# 4              Empreendimento de Geração Distribuída.
# 5   Nome do Município onde atribuído pelo IBGE em ...
# 6                                                 NaN
# 7                             de Geração Distribuída.
# 8       Sigla de identificação do tipo de consumidor:
# 9                                PJ – Pessoa Jurídica
# 10                                 PF – Pessoa Física
# 11  Cadeia de caracteres referente ao número de ca...
# 12  Pessoa Jurídica (CNPJ) do proprietário do Empr...
# 13                                        Distribuída
# 14  Nome do titular do Empreendimento de Geração D...
# 15    Código do Empreendimento de Geração Distribuída
# 16  Data da última atualização cadastral do empree...
# 17  Sigla da modalidade ao qual o empreendimento d...
# 18                                   classificado em:
# 19    P - Com Microgeração ou Minigeração distribuída
# 20          R - Caracterizada como autoconsumo remoto
# 21       C - Caracterizada como Geração compartilhada
# 22  M - Integrante de empreendimento de múltiplas ...
# 23  Modalidade ao qual o empreendimento de geração...
# 24                                                em:
# 25        Com Microgeração ou Minigeração distribuída
# 26              Caracterizada como autoconsumo remoto
# 27           Caracterizada como Geração compartilhada
# 28  Integrante de empreendimento de múltiplas UC (...
#                  Unnamed: 0            Unnamed: 1 Unnamed: 2  \
# 0        QtdUCRecebeCredito              Numérico       16,2
# 1                       NaN                   NaN        NaN
# 2                       NaN                   NaN        NaN
# 3                       NaN                   NaN        NaN
# 4                       NaN                   NaN        NaN
# 5                       NaN                   NaN        NaN
# 6            SigTipoGeracao  Cadeia de caracteres         10
# 7                       NaN                   NaN        NaN
# 8                       NaN                   NaN        NaN
# 9                       NaN                   NaN        NaN
# 10                      NaN                   NaN        NaN
# 11                      NaN                   NaN        NaN
# 12          DscFonteGeracao  Cadeia de caracteres         50
# 13                      NaN                   NaN        NaN
# 14                      NaN                   NaN        NaN
# 15                 DscPorte  Cadeia de caracteres         12
# 16                      NaN                   NaN        NaN
# 17                      NaN                   NaN        NaN
# 18  NumCoordNEmpreendimento              Numérico       20,1
# 19                      NaN                   NaN        NaN
# 20                      NaN                   NaN        NaN
# 21  NumCoordEEmpreendimento              Numérico       20,1
# 22                      NaN                   NaN        NaN
# 23                      NaN                   NaN        NaN
# 24   MdaPotenciaInstaladakW                Medida        6,2
# 25                      NaN                   NaN        NaN
# 26            NomSubEstacao  Cadeia de caracteres         50
# 27                      NaN                   NaN        NaN
# 28             NumCoordESub              Numérico       20,1
# 29                      NaN                   NaN        NaN
# 30                      NaN                   NaN        NaN
# 31             NumCoordNSub              Numérico       20,1
# 32                      NaN                   NaN        NaN
#
#    Quantidade de UC (Unidades Consumidoras) menores que pertencem a essa UC
# 0                                                 NaN
# 1                               (Unidade Consumidora)
# 2     Abreviação do tipo de geração. Classificado em:
# 3                            UTN - Usina Termonuclear
# 4                            UTE - Usina Termelétrica
# 5                            UHE - Usina Hidrelétrica
# 6           UFV - Central Geradora Solar Fotovoltaica
# 7                  PCH - Pequena Central Hidrelétrica
# 8                       EOL - Central Geradora Eólica
# 9                CGU - Central Geradora Undi-elétrica
# 10                CGH - Central Geradora Hidrelétrica
# 11  Descrição do combustível usado pelo empreendim...
# 12                                                NaN
# 13                                              etc.)
# 14  Porte do Empreendimento de Geração Distribuída...
# 15                                                NaN
# 16                                       Minigeração)
# 17  Latitude aproximada em grau decimal do ponto c...
# 18                                                NaN
# 19                                     empreendimento
# 20  Longitude aproximada em grau decimal do ponto ...
# 21                                                NaN
# 22                                     empreendimento
# 23  Armazena os dados expressos em quantidades e p...
# 24  (quilowatt), definida pela somatória das potên...
# 25          módulos da central de geração distribuída
# 26     Nome da SubEstação vinculada ao empreendimento
# 27  Latitude aproximada em grau decimal do ponto c...
# 28                                                NaN
# 29                                         SubEstação
# 30  Longitude aproximada em grau decimal do ponto ...
# 31                                                NaN
# 32                                         SubEstação

# %%
df_tab1 = tabula.read_pdf(arquivo, pages=["3"])
df_tab2 = tabula.read_pdf(arquivo, pages=["4"])
df_tab3 = tabula.read_pdf(arquivo, pages=["5"])

# %%
df_tab1[0].columns = df_tab1[0].iloc[0]

# %%
df_tab1 = df_tab1[0]
df_tab2 = df_tab2[0]
df_tab3 = df_tab3[0]

# %%
display(df_tab1)
# Out:
# 0             Nome do Campo          Tipo de dado  campo  \
# 0             Nome do Campo          Tipo de dado  campo
# 1                       NaN                   NaN    NaN
# 2   DatGeracaoConjuntoDados          data simples    NaN
# 3                       NaN                   NaN    NaN
# 4      AnmPeriodoReferencia  Cadeia de caracteres      7
# 5      NumCNPJDistribuidora  Cadeia de caracteres     14
# 6                 SigAgente  Cadeia de caracteres     20
# 7                 NomAgente  Cadeia de caracteres    200
# 8          CodClasseConsumo              Numérico    NaN
# 9          DscClasseConsumo  Cadeia de caracteres     20
# 10     CodSubGrupoTarifario              Numérico    NaN
# 11                      NaN                   NaN    NaN
# 12                      NaN                   NaN    NaN
# 13                      NaN                   NaN    NaN
# 14                      NaN                   NaN    NaN
# 15                      NaN                   NaN    NaN
# 16     DscSubGrupoTarifario  Cadeia de caracteres     10
# 17                      NaN                   NaN    NaN
# 18                      NaN                   NaN    NaN
# 19                      NaN                   NaN    NaN
# 20                      NaN                   NaN    NaN
# 21                      NaN                   NaN    NaN
# 22                      NaN                   NaN    NaN
# 23                CodUFibge  Cadeia de caracteres      2
# 24                      NaN                   NaN    NaN
# 25                      NaN                   NaN    NaN
# 26                    SigUF  Cadeia de caracteres      2
# 27                      NaN                   NaN    NaN
# 28                      NaN                   NaN    NaN
# 29                CodRegiao  Cadeia de caracteres      4
# 30                      NaN                   NaN    NaN
#
# 0                                           Descrição
# 0                                           Descrição
# 1   Data e hora do processamento de carga automáti...
# 2                                                 NaN
# 3            publicação do conjunto de dados abertos.
# 4                   Ano e mês de referência dos dados
# 5             Cadastro Nacional de Pessoas Jurídicas.
# 6   Sigla que abrevia o nome do Agente de Geração ...
# 7               Nome do Agente de Geração Distribuída
# 8   Código que representa a classificação de consu...
# 9   Descrição da classificação de consumo das unid...
# 10     Código que representa os subgrupos tarifários.
# 11  Grupamento de unidades consumidoras de acordo ...
# 12  A1 - tensão de fornecimento igual ou superior ...
# 13      A2 - tensão de fornecimento de 88 kV a 138 kV
# 14               A3 - tensão de fornecimento de 69 kV
# 15      A3a - tensão de fornecimento de 30 kV a 44 kV
# 16      A4 - tensão de fornecimento de 2,3 kV a 25 kV
# 17                                   AS - subterrâneo
# 18                                   B1 - residencial
# 19                                         B2 - rural
# 20                                B3 - demais classes
# 21                            B4 - iluminação pública
# 22  Código do IBGE referente ao Estado do Brasil e...
# 23                                                NaN
# 24                            de Geração Distribuída.
# 25  Sigla do IBGE referente ao Estado do Brasil em...
# 26                                                NaN
# 27                               Geração Distribuída.
# 28  Código Externo do IBGE referente a Meso Região...
# 29                                                NaN
# 30             Empreendimento de Geração Distribuída.

# %%
df_tab1 = df_tab1.drop(0)

# %%
display(df_tab1)
# Out:
# 0             Nome do Campo          Tipo de dado campo  \
# 1                       NaN                   NaN   NaN
# 2   DatGeracaoConjuntoDados          data simples   NaN
# 3                       NaN                   NaN   NaN
# 4      AnmPeriodoReferencia  Cadeia de caracteres     7
# 5      NumCNPJDistribuidora  Cadeia de caracteres    14
# 6                 SigAgente  Cadeia de caracteres    20
# 7                 NomAgente  Cadeia de caracteres   200
# 8          CodClasseConsumo              Numérico   NaN
# 9          DscClasseConsumo  Cadeia de caracteres    20
# 10     CodSubGrupoTarifario              Numérico   NaN
# 11                      NaN                   NaN   NaN
# 12                      NaN                   NaN   NaN
# 13                      NaN                   NaN   NaN
# 14                      NaN                   NaN   NaN
# 15                      NaN                   NaN   NaN
# 16     DscSubGrupoTarifario  Cadeia de caracteres    10
# 17                      NaN                   NaN   NaN
# 18                      NaN                   NaN   NaN
# 19                      NaN                   NaN   NaN
# 20                      NaN                   NaN   NaN
# 21                      NaN                   NaN   NaN
# 22                      NaN                   NaN   NaN
# 23                CodUFibge  Cadeia de caracteres     2
# 24                      NaN                   NaN   NaN
# 25                      NaN                   NaN   NaN
# 26                    SigUF  Cadeia de caracteres     2
# 27                      NaN                   NaN   NaN
# 28                      NaN                   NaN   NaN
# 29                CodRegiao  Cadeia de caracteres     4
# 30                      NaN                   NaN   NaN
#
# 0                                           Descrição
# 1   Data e hora do processamento de carga automáti...
# 2                                                 NaN
# 3            publicação do conjunto de dados abertos.
# 4                   Ano e mês de referência dos dados
# 5             Cadastro Nacional de Pessoas Jurídicas.
# 6   Sigla que abrevia o nome do Agente de Geração ...
# 7               Nome do Agente de Geração Distribuída
# 8   Código que representa a classificação de consu...
# 9   Descrição da classificação de consumo das unid...
# 10     Código que representa os subgrupos tarifários.
# 11  Grupamento de unidades consumidoras de acordo ...
# 12  A1 - tensão de fornecimento igual ou superior ...
# 13      A2 - tensão de fornecimento de 88 kV a 138 kV
# 14               A3 - tensão de fornecimento de 69 kV
# 15      A3a - tensão de fornecimento de 30 kV a 44 kV
# 16      A4 - tensão de fornecimento de 2,3 kV a 25 kV
# 17                                   AS - subterrâneo
# 18                                   B1 - residencial
# 19                                         B2 - rural
# 20                                B3 - demais classes
# 21                            B4 - iluminação pública
# 22  Código do IBGE referente ao Estado do Brasil e...
# 23                                                NaN
# 24                            de Geração Distribuída.
# 25  Sigla do IBGE referente ao Estado do Brasil em...
# 26                                                NaN
# 27                               Geração Distribuída.
# 28  Código Externo do IBGE referente a Meso Região...
# 29                                                NaN
# 30             Empreendimento de Geração Distribuída.

# %%
df_tab1_corrigida = pd.DataFrame()
df_tab2_corrigida = pd.DataFrame()
df_tab3_corrigida = pd.DataFrame()

# %%
df_tab1_corrigida[["Nome do Campo","Tipo de dado","Tamanho do Campo"]] = df_tab1[["Nome do Campo","Tipo de dado","campo"]]
df_tab1_corrigida = df_tab1_corrigida.dropna(how='all')

# %%
df_tab1_corrigida = df_tab1_corrigida.fillna('-')
display(df_tab1_corrigida)
# Out:
#               Nome do Campo          Tipo de dado Tamanho do Campo
# 2   DatGeracaoConjuntoDados          data simples                -
# 4      AnmPeriodoReferencia  Cadeia de caracteres                7
# 5      NumCNPJDistribuidora  Cadeia de caracteres               14
# 6                 SigAgente  Cadeia de caracteres               20
# 7                 NomAgente  Cadeia de caracteres              200
# 8          CodClasseConsumo              Numérico                -
# 9          DscClasseConsumo  Cadeia de caracteres               20
# 10     CodSubGrupoTarifario              Numérico                -
# 16     DscSubGrupoTarifario  Cadeia de caracteres               10
# 23                CodUFibge  Cadeia de caracteres                2
# 26                    SigUF  Cadeia de caracteres                2
# 29                CodRegiao  Cadeia de caracteres                4

# %%
df_tab1_corrigida["Descrição"] = (['Data e hora do processamento de carga automática no momento da geração para publicação do conjunto de dados abertos.','Ano e mês de referência dos dados',
                                   'Cadastro Nacional de Pessoas Jurídicas.','Sigla que abrevia o nome do Agente de Geração Distribuída.','Nome do Agente de Geração Distribuída',
                                   'Código que representa a classificação de consumo das unidades consumidoras','Descrição da classificação de consumo das unidades consumidoras',
                                  'Código que representa os subgrupos tarifários.', 'Grupamento de unidades consumidoras de acordo com os grupos tarifários:\nA1 - tensão de fornecimento igual ou superior a 230 kV\nA2 - tensão de fornecimento de 88 kV a 138 kV\nA3 - tensão de fornecimento de 69 kV\nA3a - tensão de fornecimento de 30 kV a 44 kV\nA4 - tensão de fornecimento de 2,3 kV a 25 kV\nAS - subterrâneo\nB1 - residencial\nB2 - rural\nB3 - demais classes\nB4 - iluminação pública',
                                  'Código do IBGE referente ao Estado do Brasil em que se situa o Empreendimento de Geração Distribuída.', 'Sigla do IBGE referente ao Estado do Brasil em que se situa o Empreendimento de  Geração Distribuída.',
                                  'Código Externo do IBGE referente a Meso Região em que se situa o Empreendimento de Geração Distribuída.'])

# %%
display(df_tab1_corrigida)
# Out:
#               Nome do Campo          Tipo de dado Tamanho do Campo  \
# 2   DatGeracaoConjuntoDados          data simples                -
# 4      AnmPeriodoReferencia  Cadeia de caracteres                7
# 5      NumCNPJDistribuidora  Cadeia de caracteres               14
# 6                 SigAgente  Cadeia de caracteres               20
# 7                 NomAgente  Cadeia de caracteres              200
# 8          CodClasseConsumo              Numérico                -
# 9          DscClasseConsumo  Cadeia de caracteres               20
# 10     CodSubGrupoTarifario              Numérico                -
# 16     DscSubGrupoTarifario  Cadeia de caracteres               10
# 23                CodUFibge  Cadeia de caracteres                2
# 26                    SigUF  Cadeia de caracteres                2
# 29                CodRegiao  Cadeia de caracteres                4
#
#                                             Descrição
# 2   Data e hora do processamento de carga automáti...
# 4                   Ano e mês de referência dos dados
# 5             Cadastro Nacional de Pessoas Jurídicas.
# 6   Sigla que abrevia o nome do Agente de Geração ...
# 7               Nome do Agente de Geração Distribuída
# 8   Código que representa a classificação de consu...
# 9   Descrição da classificação de consumo das unid...
# 10     Código que representa os subgrupos tarifários.
# 16  Grupamento de unidades consumidoras de acordo ...
# 23  Código do IBGE referente ao Estado do Brasil e...
# 26  Sigla do IBGE referente ao Estado do Brasil em...
# 29  Código Externo do IBGE referente a Meso Região...

# %% [markdown]
# TABELA 1 TRATADA POR COMPLETO -
# INICIANDO TRATAMENTO DA TABELA 2 - SEQUÊNCIA DA TABELA 1

# %%
display(df_tab2)
# Out:
#                       Unnamed: 0            Unnamed: 1  Unnamed: 2  \
# 0                      NomRegiao  Cadeia de caracteres        50.0
# 1                            NaN                   NaN         NaN
# 2                            NaN                   NaN         NaN
# 3               CodMunicipioIbge              Numérico         NaN
# 4                            NaN                   NaN         NaN
# 5                            NaN                   NaN         NaN
# 6                   NomMunicipio  Cadeia de caracteres        40.0
# 7                            NaN                   NaN         NaN
# 8                            NaN                   NaN         NaN
# 9              SigTipoConsumidor  Cadeia de caracteres         2.0
# 10                           NaN                   NaN         NaN
# 11                           NaN                   NaN         NaN
# 12                    NumCpfCnpj  Cadeia de caracteres        14.0
# 13                           NaN                   NaN         NaN
# 14      NomTitularEmpreendimento  Cadeia de caracteres      8000.0
# 15             CodEmpreendimento  Cadeia de caracteres        21.0
# 16  DthAtualizaCadastralEmpreend             Data hora         NaN
# 17                           NaN                   NaN         NaN
# 18                           NaN                   NaN         NaN
# 19                           NaN                   NaN         NaN
# 20   SigModalidadeEmpreendimento  Cadeia de caracteres         1.0
# 21                           NaN                   NaN         NaN
# 22                           NaN                   NaN         NaN
# 23                           NaN                   NaN         NaN
# 24                           NaN                   NaN         NaN
# 25                           NaN                   NaN         NaN
# 26       DscModalidadeHabilitado  Cadeia de caracteres        50.0
# 27                           NaN                   NaN         NaN
# 28                           NaN                   NaN         NaN
#
#    Nome da Meso Região atribuído pelo IBGE em que se situa o Empreendimento de
# 0                                                 NaN
# 1                                Geração Distribuída.
# 2   Código Externo do IBGE referente ao Município ...
# 3                                                 NaN
# 4              Empreendimento de Geração Distribuída.
# 5   Nome do Município onde atribuído pelo IBGE em ...
# 6                                                 NaN
# 7                             de Geração Distribuída.
# 8       Sigla de identificação do tipo de consumidor:
# 9                                PJ – Pessoa Jurídica
# 10                                 PF – Pessoa Física
# 11  Cadeia de caracteres referente ao número de ca...
# 12  Pessoa Jurídica (CNPJ) do proprietário do Empr...
# 13                                        Distribuída
# 14  Nome do titular do Empreendimento de Geração D...
# 15    Código do Empreendimento de Geração Distribuída
# 16  Data da última atualização cadastral do empree...
# 17  Sigla da modalidade ao qual o empreendimento d...
# 18                                   classificado em:
# 19    P - Com Microgeração ou Minigeração distribuída
# 20          R - Caracterizada como autoconsumo remoto
# 21       C - Caracterizada como Geração compartilhada
# 22  M - Integrante de empreendimento de múltiplas ...
# 23  Modalidade ao qual o empreendimento de geração...
# 24                                                em:
# 25        Com Microgeração ou Minigeração distribuída
# 26              Caracterizada como autoconsumo remoto
# 27           Caracterizada como Geração compartilhada
# 28  Integrante de empreendimento de múltiplas UC (...

# %%
df_tab2_corrigida[["Nome do Campo","Tipo de dado","Tamanho do Campo"]] = df_tab2[["Unnamed: 0","Unnamed: 1","Unnamed: 2"]]
df_tab2_corrigida = df_tab2_corrigida.dropna(how='all')

# %%
df_tab2_corrigida = df_tab2_corrigida.fillna('-')
display(df_tab2_corrigida)
# Out:
#                    Nome do Campo          Tipo de dado Tamanho do Campo
# 0                      NomRegiao  Cadeia de caracteres             50.0
# 3               CodMunicipioIbge              Numérico                -
# 6                   NomMunicipio  Cadeia de caracteres             40.0
# 9              SigTipoConsumidor  Cadeia de caracteres              2.0
# 12                    NumCpfCnpj  Cadeia de caracteres             14.0
# 14      NomTitularEmpreendimento  Cadeia de caracteres           8000.0
# 15             CodEmpreendimento  Cadeia de caracteres             21.0
# 16  DthAtualizaCadastralEmpreend             Data hora                -
# 20   SigModalidadeEmpreendimento  Cadeia de caracteres              1.0
# 26       DscModalidadeHabilitado  Cadeia de caracteres             50.0

# %%
df_tab2_corrigida["Descrição"] = (['Nome da Meso Região atribuído pelo IBGE em que se situa o Empreendimento de Geração Distribuída.',
                                   'Código Externo do IBGE referente ao Município em que se situa o Empreendimento de Geração Distribuída.',
                                  'Nome do Município onde atribuído pelo IBGE em que se situa o Empreendimento de Geração Distribuída.',
                                   'Sigla de identificação do tipo de consumidor:\nPJ – Pessoa Jurídica\nPF – Pessoa Física',
                                  'Cadeia de caracteres referente ao número de cadastro de Pessoa Física (CPF) ou Pessoa Jurídica (CNPJ) do proprietário do Empreendimento de Geração Distribuída',
                                  'Nome do titular do Empreendimento de Geração Distribuída','Código do Empreendimento de Geração Distribuída',
                                   'Data da última atualização cadastral do empreendimento de distribuição.',
                                  'Sigla da modalidade ao qual o empreendimento de geração está habilitado, classificado em:\nP - Com Microgeração ou Minigeração distribuída\nR - Caracterizada como autoconsumo remoto\nC - Caracterizada como Geração compartilhada\nM - Integrante de empreendimento de múltiplas UC - Unidades Consumidoras',
                                   'Modalidade ao qual o empreendimento de geração está habilitado, classificado em:\nCom Microgeração ou Minigeração distribuída\nCaracterizada como autoconsumo remoto\nCaracterizada como Geração compartilhada\nIntegrante de empreendimento de múltiplas UC - Unidades Consumidoras'])

# %%
display(df_tab2_corrigida)
# Out:
#                    Nome do Campo          Tipo de dado Tamanho do Campo  \
# 0                      NomRegiao  Cadeia de caracteres             50.0
# 3               CodMunicipioIbge              Numérico                -
# 6                   NomMunicipio  Cadeia de caracteres             40.0
# 9              SigTipoConsumidor  Cadeia de caracteres              2.0
# 12                    NumCpfCnpj  Cadeia de caracteres             14.0
# 14      NomTitularEmpreendimento  Cadeia de caracteres           8000.0
# 15             CodEmpreendimento  Cadeia de caracteres             21.0
# 16  DthAtualizaCadastralEmpreend             Data hora                -
# 20   SigModalidadeEmpreendimento  Cadeia de caracteres              1.0
# 26       DscModalidadeHabilitado  Cadeia de caracteres             50.0
#
#                                             Descrição
# 0   Nome da Meso Região atribuído pelo IBGE em que...
# 3   Código Externo do IBGE referente ao Município ...
# 6   Nome do Município onde atribuído pelo IBGE em ...
# 9   Sigla de identificação do tipo de consumidor:\...
# 12  Cadeia de caracteres referente ao número de ca...
# 14  Nome do titular do Empreendimento de Geração D...
# 15    Código do Empreendimento de Geração Distribuída
# 16  Data da última atualização cadastral do empree...
# 20  Sigla da modalidade ao qual o empreendimento d...
# 26  Modalidade ao qual o empreendimento de geração...

# %% [markdown]
# TABELA 2 TRATADA POR COMPLETO -
# INICIANDO TRATAMENTO DA TABELA 3 - SEQUÊNCIA DA TABELA 1

# %%
display(df_tab3)
# Out:
#                  Unnamed: 0            Unnamed: 1 Unnamed: 2  \
# 0        QtdUCRecebeCredito              Numérico       16,2
# 1                       NaN                   NaN        NaN
# 2                       NaN                   NaN        NaN
# 3                       NaN                   NaN        NaN
# 4                       NaN                   NaN        NaN
# 5                       NaN                   NaN        NaN
# 6            SigTipoGeracao  Cadeia de caracteres         10
# 7                       NaN                   NaN        NaN
# 8                       NaN                   NaN        NaN
# 9                       NaN                   NaN        NaN
# 10                      NaN                   NaN        NaN
# 11                      NaN                   NaN        NaN
# 12          DscFonteGeracao  Cadeia de caracteres         50
# 13                      NaN                   NaN        NaN
# 14                      NaN                   NaN        NaN
# 15                 DscPorte  Cadeia de caracteres         12
# 16                      NaN                   NaN        NaN
# 17                      NaN                   NaN        NaN
# 18  NumCoordNEmpreendimento              Numérico       20,1
# 19                      NaN                   NaN        NaN
# 20                      NaN                   NaN        NaN
# 21  NumCoordEEmpreendimento              Numérico       20,1
# 22                      NaN                   NaN        NaN
# 23                      NaN                   NaN        NaN
# 24   MdaPotenciaInstaladakW                Medida        6,2
# 25                      NaN                   NaN        NaN
# 26            NomSubEstacao  Cadeia de caracteres         50
# 27                      NaN                   NaN        NaN
# 28             NumCoordESub              Numérico       20,1
# 29                      NaN                   NaN        NaN
# 30                      NaN                   NaN        NaN
# 31             NumCoordNSub              Numérico       20,1
# 32                      NaN                   NaN        NaN
#
#    Quantidade de UC (Unidades Consumidoras) menores que pertencem a essa UC
# 0                                                 NaN
# 1                               (Unidade Consumidora)
# 2     Abreviação do tipo de geração. Classificado em:
# 3                            UTN - Usina Termonuclear
# 4                            UTE - Usina Termelétrica
# 5                            UHE - Usina Hidrelétrica
# 6           UFV - Central Geradora Solar Fotovoltaica
# 7                  PCH - Pequena Central Hidrelétrica
# 8                       EOL - Central Geradora Eólica
# 9                CGU - Central Geradora Undi-elétrica
# 10                CGH - Central Geradora Hidrelétrica
# 11  Descrição do combustível usado pelo empreendim...
# 12                                                NaN
# 13                                              etc.)
# 14  Porte do Empreendimento de Geração Distribuída...
# 15                                                NaN
# 16                                       Minigeração)
# 17  Latitude aproximada em grau decimal do ponto c...
# 18                                                NaN
# 19                                     empreendimento
# 20  Longitude aproximada em grau decimal do ponto ...
# 21                                                NaN
# 22                                     empreendimento
# 23  Armazena os dados expressos em quantidades e p...
# 24  (quilowatt), definida pela somatória das potên...
# 25          módulos da central de geração distribuída
# 26     Nome da SubEstação vinculada ao empreendimento
# 27  Latitude aproximada em grau decimal do ponto c...
# 28                                                NaN
# 29                                         SubEstação
# 30  Longitude aproximada em grau decimal do ponto ...
# 31                                                NaN
# 32                                         SubEstação

# %%
df_tab3_corrigida[["Nome do Campo","Tipo de dado","Tamanho do Campo"]] = df_tab3[["Unnamed: 0","Unnamed: 1","Unnamed: 2"]]
df_tab3_corrigida = df_tab3_corrigida.dropna(how='all')

# %%
df_tab3_corrigida = df_tab3_corrigida.fillna('-')
display(df_tab3_corrigida)
# Out:
#               Nome do Campo          Tipo de dado Tamanho do Campo
# 0        QtdUCRecebeCredito              Numérico             16,2
# 6            SigTipoGeracao  Cadeia de caracteres               10
# 12          DscFonteGeracao  Cadeia de caracteres               50
# 15                 DscPorte  Cadeia de caracteres               12
# 18  NumCoordNEmpreendimento              Numérico             20,1
# 21  NumCoordEEmpreendimento              Numérico             20,1
# 24   MdaPotenciaInstaladakW                Medida              6,2
# 26            NomSubEstacao  Cadeia de caracteres               50
# 28             NumCoordESub              Numérico             20,1
# 31             NumCoordNSub              Numérico             20,1

# %%
df_tab3_corrigida["Descrição"] = (['Quantidade de UC (Unidades Consumidoras) menores que pertencem a essa UC (Unidade Consumidora)',
                                  'Abreviação do tipo de geração. Classificado em:\nUTN - Usina Termonuclear\nUTE - Usina Termelétrica\nUHE - Usina Hidrelétrica\nUFV - Central Geradora Solar Fotovoltaica\nPCH - Pequena Central Hidrelétrica\nEOL - Central Geradora Eólica\nCGU - Central Geradora Undi-elétrica\nCGH - Central Geradora Hidrelétrica',
                                  'Descrição do combustível usado pelo empreendimento (Etanol, Casca de Arroz, etc.)',
                                  'Porte do Empreendimento de Geração Distribuída (Microgeração ou Minigeração)',
                                  'Latitude aproximada em grau decimal do ponto centroide de localização do empreendimento',
                                  'Longitude aproximada em grau decimal do ponto centroide de localização do empreendimento',
                                  'Armazena os dados expressos em quantidades e potência instalada em kW (quilowatt), definida pela somatória das potências elétricas ativas nominais dos módulos da central de geração distribuída',
                                  'Nome da SubEstação vinculada ao empreendimento','Latitude aproximada em grau decimal do ponto centroide de localização da SubEstação',
                                  'Longitude aproximada em grau decimal do ponto centroide de localização da SubEstação'])

# %%
display(df_tab3_corrigida)
# Out:
#               Nome do Campo          Tipo de dado Tamanho do Campo  \
# 0        QtdUCRecebeCredito              Numérico             16,2
# 6            SigTipoGeracao  Cadeia de caracteres               10
# 12          DscFonteGeracao  Cadeia de caracteres               50
# 15                 DscPorte  Cadeia de caracteres               12
# 18  NumCoordNEmpreendimento              Numérico             20,1
# 21  NumCoordEEmpreendimento              Numérico             20,1
# 24   MdaPotenciaInstaladakW                Medida              6,2
# 26            NomSubEstacao  Cadeia de caracteres               50
# 28             NumCoordESub              Numérico             20,1
# 31             NumCoordNSub              Numérico             20,1
#
#                                             Descrição
# 0   Quantidade de UC (Unidades Consumidoras) menor...
# 6   Abreviação do tipo de geração. Classificado em...
# 12  Descrição do combustível usado pelo empreendim...
# 15  Porte do Empreendimento de Geração Distribuída...
# 18  Latitude aproximada em grau decimal do ponto c...
# 21  Longitude aproximada em grau decimal do ponto ...
# 24  Armazena os dados expressos em quantidades e p...
# 26     Nome da SubEstação vinculada ao empreendimento
# 28  Latitude aproximada em grau decimal do ponto c...
# 31  Longitude aproximada em grau decimal do ponto ...

# %%
dict_tabelaCompleta = pd.concat([df_tab1_corrigida,df_tab1_corrigida,df_tab3_corrigida],ignore_index = True)

# %%
display(dict_tabelaCompleta)
# Out:
#               Nome do Campo          Tipo de dado Tamanho do Campo  \
# 0   DatGeracaoConjuntoDados          data simples                -
# 1      AnmPeriodoReferencia  Cadeia de caracteres                7
# 2      NumCNPJDistribuidora  Cadeia de caracteres               14
# 3                 SigAgente  Cadeia de caracteres               20
# 4                 NomAgente  Cadeia de caracteres              200
# 5          CodClasseConsumo              Numérico                -
# 6          DscClasseConsumo  Cadeia de caracteres               20
# 7      CodSubGrupoTarifario              Numérico                -
# 8      DscSubGrupoTarifario  Cadeia de caracteres               10
# 9                 CodUFibge  Cadeia de caracteres                2
# 10                    SigUF  Cadeia de caracteres                2
# 11                CodRegiao  Cadeia de caracteres                4
# 12  DatGeracaoConjuntoDados          data simples                -
# 13     AnmPeriodoReferencia  Cadeia de caracteres                7
# 14     NumCNPJDistribuidora  Cadeia de caracteres               14
# 15                SigAgente  Cadeia de caracteres               20
# 16                NomAgente  Cadeia de caracteres              200
# 17         CodClasseConsumo              Numérico                -
# 18         DscClasseConsumo  Cadeia de caracteres               20
# 19     CodSubGrupoTarifario              Numérico                -
# 20     DscSubGrupoTarifario  Cadeia de caracteres               10
# 21                CodUFibge  Cadeia de caracteres                2
# 22                    SigUF  Cadeia de caracteres                2
# 23                CodRegiao  Cadeia de caracteres                4
# 24       QtdUCRecebeCredito              Numérico             16,2
# 25           SigTipoGeracao  Cadeia de caracteres               10
# 26          DscFonteGeracao  Cadeia de caracteres               50
# 27                 DscPorte  Cadeia de caracteres               12
# 28  NumCoordNEmpreendimento              Numérico             20,1
# 29  NumCoordEEmpreendimento              Numérico             20,1
# 30   MdaPotenciaInstaladakW                Medida              6,2
# 31            NomSubEstacao  Cadeia de caracteres               50
# 32             NumCoordESub              Numérico             20,1
# 33             NumCoordNSub              Numérico             20,1
#
#                                             Descrição
# 0   Data e hora do processamento de carga automáti...
# 1                   Ano e mês de referência dos dados
# 2             Cadastro Nacional de Pessoas Jurídicas.
# 3   Sigla que abrevia o nome do Agente de Geração ...
# 4               Nome do Agente de Geração Distribuída
# 5   Código que representa a classificação de consu...
# 6   Descrição da classificação de consumo das unid...
# 7      Código que representa os subgrupos tarifários.
# 8   Grupamento de unidades consumidoras de acordo ...
# 9   Código do IBGE referente ao Estado do Brasil e...
# 10  Sigla do IBGE referente ao Estado do Brasil em...
# 11  Código Externo do IBGE referente a Meso Região...
# 12  Data e hora do processamento de carga automáti...
# 13                  Ano e mês de referência dos dados
# 14            Cadastro Nacional de Pessoas Jurídicas.
# 15  Sigla que abrevia o nome do Agente de Geração ...
# 16              Nome do Agente de Geração Distribuída
# 17  Código que representa a classificação de consu...
# 18  Descrição da classificação de consumo das unid...
# 19     Código que representa os subgrupos tarifários.
# 20  Grupamento de unidades consumidoras de acordo ...
# 21  Código do IBGE referente ao Estado do Brasil e...
# 22  Sigla do IBGE referente ao Estado do Brasil em...
# 23  Código Externo do IBGE referente a Meso Região...
# 24  Quantidade de UC (Unidades Consumidoras) menor...
# 25  Abreviação do tipo de geração. Classificado em...
# 26  Descrição do combustível usado pelo empreendim...
# 27  Porte do Empreendimento de Geração Distribuída...
# 28  Latitude aproximada em grau decimal do ponto c...
# 29  Longitude aproximada em grau decimal do ponto ...
# 30  Armazena os dados expressos em quantidades e p...
# 31     Nome da SubEstação vinculada ao empreendimento
# 32  Latitude aproximada em grau decimal do ponto c...
# 33  Longitude aproximada em grau decimal do ponto ...

# %%
dict_tabelaCompleta.to_csv("data_base/dict_Aneel_AnaliseDados.csv")

# %%
display(dict_tabelaCompleta.sort_values(by="Nome do Campo"))
# Out:
#               Nome do Campo          Tipo de dado Tamanho do Campo  \
# 1      AnmPeriodoReferencia  Cadeia de caracteres                7
# 13     AnmPeriodoReferencia  Cadeia de caracteres                7
# 5          CodClasseConsumo              Numérico                -
# 17         CodClasseConsumo              Numérico                -
# 11                CodRegiao  Cadeia de caracteres                4
# 23                CodRegiao  Cadeia de caracteres                4
# 19     CodSubGrupoTarifario              Numérico                -
# 7      CodSubGrupoTarifario              Numérico                -
# 9                 CodUFibge  Cadeia de caracteres                2
# 21                CodUFibge  Cadeia de caracteres                2
# 12  DatGeracaoConjuntoDados          data simples                -
# 0   DatGeracaoConjuntoDados          data simples                -
# 6          DscClasseConsumo  Cadeia de caracteres               20
# 18         DscClasseConsumo  Cadeia de caracteres               20
# 26          DscFonteGeracao  Cadeia de caracteres               50
# 27                 DscPorte  Cadeia de caracteres               12
# 20     DscSubGrupoTarifario  Cadeia de caracteres               10
# 8      DscSubGrupoTarifario  Cadeia de caracteres               10
# 30   MdaPotenciaInstaladakW                Medida              6,2
# 16                NomAgente  Cadeia de caracteres              200
# 4                 NomAgente  Cadeia de caracteres              200
# 31            NomSubEstacao  Cadeia de caracteres               50
# 14     NumCNPJDistribuidora  Cadeia de caracteres               14
# 2      NumCNPJDistribuidora  Cadeia de caracteres               14
# 29  NumCoordEEmpreendimento              Numérico             20,1
# 32             NumCoordESub              Numérico             20,1
# 28  NumCoordNEmpreendimento              Numérico             20,1
# 33             NumCoordNSub              Numérico             20,1
# 24       QtdUCRecebeCredito              Numérico             16,2
# 15                SigAgente  Cadeia de caracteres               20
# 3                 SigAgente  Cadeia de caracteres               20
# 25           SigTipoGeracao  Cadeia de caracteres               10
# 22                    SigUF  Cadeia de caracteres                2
# 10                    SigUF  Cadeia de caracteres                2
#
#                                             Descrição
# 1                   Ano e mês de referência dos dados
# 13                  Ano e mês de referência dos dados
# 5   Código que representa a classificação de consu...
# 17  Código que representa a classificação de consu...
# 11  Código Externo do IBGE referente a Meso Região...
# 23  Código Externo do IBGE referente a Meso Região...
# 19     Código que representa os subgrupos tarifários.
# 7      Código que representa os subgrupos tarifários.
# 9   Código do IBGE referente ao Estado do Brasil e...
# 21  Código do IBGE referente ao Estado do Brasil e...
# 12  Data e hora do processamento de carga automáti...
# 0   Data e hora do processamento de carga automáti...
# 6   Descrição da classificação de consumo das unid...
# 18  Descrição da classificação de consumo das unid...
# 26  Descrição do combustível usado pelo empreendim...
# 27  Porte do Empreendimento de Geração Distribuída...
# 20  Grupamento de unidades consumidoras de acordo ...
# 8   Grupamento de unidades consumidoras de acordo ...
# 30  Armazena os dados expressos em quantidades e p...
# 16              Nome do Agente de Geração Distribuída
# 4               Nome do Agente de Geração Distribuída
# 31     Nome da SubEstação vinculada ao empreendimento
# 14            Cadastro Nacional de Pessoas Jurídicas.
# 2             Cadastro Nacional de Pessoas Jurídicas.
# 29  Longitude aproximada em grau decimal do ponto ...
# 32  Latitude aproximada em grau decimal do ponto c...
# 28  Latitude aproximada em grau decimal do ponto c...
# 33  Longitude aproximada em grau decimal do ponto ...
# 24  Quantidade de UC (Unidades Consumidoras) menor...
# 15  Sigla que abrevia o nome do Agente de Geração ...
# 3   Sigla que abrevia o nome do Agente de Geração ...
# 25  Abreviação do tipo de geração. Classificado em...
# 22  Sigla do IBGE referente ao Estado do Brasil em...
# 10  Sigla do IBGE referente ao Estado do Brasil em...

# %%
dict_Novas_Colunas_Eolica = {'Nome do Campo': ["DatGeracaoConjuntoDados","CodGeracaoDistribuida","NomFabricanteAerogerador","DscModeloAerogerador","MdaPotenciaInstalada","MdaAlturaPa","DatConexao","IdcEixoRotor"],'Tipo de Dado':['Data Simples','Cadeia de caracteres','Cadeia de caracteres','Cadeia de caracteres','Numérico','Numérico','Data Simples','Cadeia de caracteres'],'Tamanho do Campo':['-',21,100,100,6.2,5.2,'-',1],'Descrição':['Data do processamento de carga automática no momento da geração para publicação do conjunto de dados abertos.','Código da Unidade Geradora','Nome do fabricante da unidade aerogeradora','Descrição do modelo da unidade aerogeradora','Medida da potência instalada','Medida da altura da pá','Data da conexão da Unidade Geradora','Identificador do tipo do eixo rotor. Valores de domínio: H; V.H - Horizontal; V - Vertical.'] }

df_dictEolicaInfoTec = pd.DataFrame(dict_Novas_Colunas_Eolica)

# %%
display(df_dictEolicaInfoTec)
# Out:
#               Nome do Campo          Tipo de Dado Tamanho do Campo  \
# 0   DatGeracaoConjuntoDados          Data Simples                -
# 1     CodGeracaoDistribuida  Cadeia de caracteres               21
# 2  NomFabricanteAerogerador  Cadeia de caracteres              100
# 3      DscModeloAerogerador  Cadeia de caracteres              100
# 4      MdaPotenciaInstalada              Numérico              6.2
# 5               MdaAlturaPa              Numérico              5.2
# 6                DatConexao          Data Simples                -
# 7              IdcEixoRotor  Cadeia de caracteres                1
#
#                                            Descrição
# 0  Data do processamento de carga automática no m...
# 1                         Código da Unidade Geradora
# 2         Nome do fabricante da unidade aerogeradora
# 3        Descrição do modelo da unidade aerogeradora
# 4                       Medida da potência instalada
# 5                             Medida da altura da pá
# 6                Data da conexão da Unidade Geradora
# 7  Identificador do tipo do eixo rotor. Valores d...

# %%
dict_Novas_Colunas_Solar = {'Nome do Campo': ["DatGeracaoConjuntoDados","CodGeracaoDistribuida","MdaAreaArranjo","MdaPotenciaInstalada","NomFabricanteModulo","NomFabricanteInversor","DatConexao","MdaPotenciaModulos",'MdaPotenciaInversores','QtdModulos','NomModeloModulo','NomModeloInversor'],'Tipo de Dado':['Data Simples','Cadeia de caracteres','Numérico','Numérico','Cadeia de caracteres','Cadeia de caracteres','Data Simples','Numérico','Numérico','Numérico','Cadeia de caracteres','Cadeia de caracteres'],'Tamanho do Campo':['-',21,8.3,6.2,100,100,'-',6.2,6.2,10,100,100],'Descrição':['Data do processamento de carga automática no momento da geração para publicação do conjunto de dados abertos.','Código da Unidade Geradora','Total da área de Arranjo','Medida da potência instalada','Nome do fabricante do módulo','Nome do fabricante do inversor','Data da conexão da Unidade Geradora','Armazena os dados expressos em quantidades e potência dos módulos em MW (quilowatt), definida pela somatória das potências elétricas ativas nominais dos módulos da central de geração distribuída','Armazena os dados expressos em quantidades e potência dos inversores em MW (quilowatt), definida pela somatória das potências elétricas ativas nominais dos módulos da central de geração distribuída','Quantidade de Módulos','Nome do modelo do Módulo','Nome do modelo do Inversor'] }
df_dictFotovoltaicaInfoTec = pd.DataFrame(dict_Novas_Colunas_Solar)

# %%
display(df_dictFotovoltaicaInfoTec)
# Out:
#               Nome do Campo          Tipo de Dado Tamanho do Campo  \
# 0   DatGeracaoConjuntoDados          Data Simples                -
# 1     CodGeracaoDistribuida  Cadeia de caracteres               21
# 2            MdaAreaArranjo              Numérico              8.3
# 3      MdaPotenciaInstalada              Numérico              6.2
# 4       NomFabricanteModulo  Cadeia de caracteres              100
# 5     NomFabricanteInversor  Cadeia de caracteres              100
# 6                DatConexao          Data Simples                -
# 7        MdaPotenciaModulos              Numérico              6.2
# 8     MdaPotenciaInversores              Numérico              6.2
# 9                QtdModulos              Numérico               10
# 10          NomModeloModulo  Cadeia de caracteres              100
# 11        NomModeloInversor  Cadeia de caracteres              100
#
#                                             Descrição
# 0   Data do processamento de carga automática no m...
# 1                          Código da Unidade Geradora
# 2                            Total da área de Arranjo
# 3                        Medida da potência instalada
# 4                        Nome do fabricante do módulo
# 5                      Nome do fabricante do inversor
# 6                 Data da conexão da Unidade Geradora
# 7   Armazena os dados expressos em quantidades e p...
# 8   Armazena os dados expressos em quantidades e p...
# 9                               Quantidade de Módulos
# 10                           Nome do modelo do Módulo
# 11                         Nome do modelo do Inversor

# %%
dict_Novas_Colunas_Solar = {'Nome do Campo': ["DatGeracaoConjuntoDados","CodGeracaoDistribuida","NomRio","MdaPotenciaInstalada","DatConexao","MdaPotenciaAparente","MdaFatorPotencia","MdaTensao",'MdaNivelOperacionalMontante','MdaNivelOperacionalJusante'],'Tipo de Dado':['Data Simples','Cadeia de caracteres','Cadeia de caracteres','Numérico','Data Simples','Numérico','Numérico','Numérico','Numérico','Numérico'],'Tamanho do Campo':['-',21,50,6.2,'-',6.2,6.2,6.2,6.2,6.2],'Descrição':['Data do processamento de carga automática no momento da geração para publicação do conjunto de dados abertos.','Código da Unidade Geradora','Nome do Rio','Medida da potência instalada','Data da conexão da Unidade Geradora','Objetivo deste campo é armazenar a Potência aparente em kVA da respectiva usina.','Objetivo deste campo é armazenar o Fator de potência da respectiva usina, podendo receber valores em decimal.','Objetivo deste campo é armazenar informações da Tensão de conexão em kV da usina, podendo receber valores decimal.','O campo contém anotações sobre o nível operacional normal de montante em metros','O campo contém informações sobre o nível operacional normal de JUSANTE em metros. "Nível dágua a jusante correspondente ao somatório dos engolimentos máximos de todas as turbinas, sem considerar a influência da vazão vertida." Resolução ANEEL n. 652, de 9 de dezembro de 2003 (Diário Oficial, de 10 dez. 2003, seção 1, p. 90'] }
df_dictHidreletricaInfoTec = pd.DataFrame(dict_Novas_Colunas_Solar)

# %%
display(df_dictHidreletricaInfoTec)
# Out:
#                  Nome do Campo          Tipo de Dado Tamanho do Campo  \
# 0      DatGeracaoConjuntoDados          Data Simples                -
# 1        CodGeracaoDistribuida  Cadeia de caracteres               21
# 2                       NomRio  Cadeia de caracteres               50
# 3         MdaPotenciaInstalada              Numérico              6.2
# 4                   DatConexao          Data Simples                -
# 5          MdaPotenciaAparente              Numérico              6.2
# 6             MdaFatorPotencia              Numérico              6.2
# 7                    MdaTensao              Numérico              6.2
# 8  MdaNivelOperacionalMontante              Numérico              6.2
# 9   MdaNivelOperacionalJusante              Numérico              6.2
#
#                                            Descrição
# 0  Data do processamento de carga automática no m...
# 1                         Código da Unidade Geradora
# 2                                        Nome do Rio
# 3                       Medida da potência instalada
# 4                Data da conexão da Unidade Geradora
# 5  Objetivo deste campo é armazenar a Potência ap...
# 6  Objetivo deste campo é armazenar o Fator de po...
# 7  Objetivo deste campo é armazenar informações d...
# 8  O campo contém anotações sobre o nível operaci...
# 9  O campo contém informações sobre o nível opera...

# %%
dict_Novas_Colunas_Termeletrica = {'Nome do Campo': ["DatGeracaoConjuntoDados","CodGeracaoDistribuida","MdaPotenciaInstalada","DatConexao","DscCicloTermodinamico","DscMaquinaMotrizTermica"],'Tipo de Dado':['Data Simples','Cadeia de caracteres','Numérico','Data Simples','Cadeia de caracteres','Cadeia de caracteres'],'Tamanho do Campo':['-',21,6.2,'-',30,30],'Descrição':['Data do processamento de carga automática no momento da geração para publicação do conjunto de dados abertos.','Código da Unidade Geradora','Medida da potência instalada','Data da conexão da Unidade Geradora','Descrição do ciclo termodinâmico','Descrição do ciclo constituído por um gerador elétrico conjugado a máquina(s) motriz(es) e respectivos equipamentos, destinado a converter em energia elétrica outra forma de energia.'] }
df_dictTermeletricaInfoTec = pd.DataFrame(dict_Novas_Colunas_Solar)

# %%
display(df_dictHidreletricaInfoTec)
# Out:
#                  Nome do Campo          Tipo de Dado Tamanho do Campo  \
# 0      DatGeracaoConjuntoDados          Data Simples                -
# 1        CodGeracaoDistribuida  Cadeia de caracteres               21
# 2                       NomRio  Cadeia de caracteres               50
# 3         MdaPotenciaInstalada              Numérico              6.2
# 4                   DatConexao          Data Simples                -
# 5          MdaPotenciaAparente              Numérico              6.2
# 6             MdaFatorPotencia              Numérico              6.2
# 7                    MdaTensao              Numérico              6.2
# 8  MdaNivelOperacionalMontante              Numérico              6.2
# 9   MdaNivelOperacionalJusante              Numérico              6.2
#
#                                            Descrição
# 0  Data do processamento de carga automática no m...
# 1                         Código da Unidade Geradora
# 2                                        Nome do Rio
# 3                       Medida da potência instalada
# 4                Data da conexão da Unidade Geradora
# 5  Objetivo deste campo é armazenar a Potência ap...
# 6  Objetivo deste campo é armazenar o Fator de po...
# 7  Objetivo deste campo é armazenar informações d...
# 8  O campo contém anotações sobre o nível operaci...
# 9  O campo contém informações sobre o nível opera...

# %%
dict_tabelaCompleta = pd.concat([df_tab1_corrigida,df_tab1_corrigida,df_tab3_corrigida,df_dictEolicaInfoTec,df_dictFotovoltaicaInfoTec,df_dictHidreletricaInfoTec,df_dictTermeletricaInfoTec],ignore_index = True)

# %%
display(dict_tabelaCompleta)
# Out:
#                   Nome do Campo          Tipo de dado Tamanho do Campo  \
# 0       DatGeracaoConjuntoDados          data simples                -
# 1          AnmPeriodoReferencia  Cadeia de caracteres                7
# 2          NumCNPJDistribuidora  Cadeia de caracteres               14
# 3                     SigAgente  Cadeia de caracteres               20
# 4                     NomAgente  Cadeia de caracteres              200
# ..                          ...                   ...              ...
# 69          MdaPotenciaAparente                   NaN              6.2
# 70             MdaFatorPotencia                   NaN              6.2
# 71                    MdaTensao                   NaN              6.2
# 72  MdaNivelOperacionalMontante                   NaN              6.2
# 73   MdaNivelOperacionalJusante                   NaN              6.2
#
#                                             Descrição Tipo de Dado
# 0   Data e hora do processamento de carga automáti...          NaN
# 1                   Ano e mês de referência dos dados          NaN
# 2             Cadastro Nacional de Pessoas Jurídicas.          NaN
# 3   Sigla que abrevia o nome do Agente de Geração ...          NaN
# 4               Nome do Agente de Geração Distribuída          NaN
# ..                                                ...          ...
# 69  Objetivo deste campo é armazenar a Potência ap...     Numérico
# 70  Objetivo deste campo é armazenar o Fator de po...     Numérico
# 71  Objetivo deste campo é armazenar informações d...     Numérico
# 72  O campo contém anotações sobre o nível operaci...     Numérico
# 73  O campo contém informações sobre o nível opera...     Numérico
#
# [74 rows x 5 columns]

# %%
dict_tabelaCompleta.to_csv("data_base/dict_Aneel_AnaliseDados.csv")
